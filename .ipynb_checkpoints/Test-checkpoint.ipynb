# %%
# %ai hello
# Out:
# UsageError: Line magic function `%ai` not found.

# %%
print("Hello World")
# Out:
# Hello World

# %%
pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-1.0-py2.py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\gerha\anaconda3\lib\site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\gerha\anaconda3\lib\site-packages (from yfinance) (2.3.5)
# Requirement already satisfied: requests>=2.31 in c:\users\gerha\anaconda3\lib\site-packages (from yfinance) (2.32.5)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.12.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\gerha\anaconda3\lib\site-packages (from yfinance) (4.5.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\gerha\anaconda3\lib\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\gerha\anaconda3\lib\site-packages (from yfinance) (2.4.6)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.18.3.tar.gz (3.0 MB)
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#      ----------------- ---------------------- 1.3/3.0 MB 5.0 MB/s eta 0:00:01
#      --------------------------- ------------ 2.1/3.0 MB 5.4 MB/s eta 0:00:01
#      ---------------------------------------- 3.0/3.0 MB 4.8 MB/s  0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\gerha\anaconda3\lib\site-packages (from yfinance) (4.13.5)
# Collecting curl_cffi<0.14,>=0.7 (from yfinance)
#   Downloading curl_cffi-0.13.0-cp39-abi3-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\gerha\anaconda3\lib\site-packages (from yfinance) (6.33.2)
# Requirement already satisfied: websockets>=13.0 in c:\users\gerha\anaconda3\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\gerha\anaconda3\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\gerha\anaconda3\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2025.11.12)
# Requirement already satisfied: soupsieve>1.2 in c:\users\gerha\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\gerha\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: pycparser in c:\users\gerha\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (2.23)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gerha\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gerha\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\gerha\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\gerha\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gerha\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gerha\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.5.0)
# Downloading yfinance-1.0-py2.py3-none-any.whl (127 kB)
# Downloading curl_cffi-0.13.0-cp39-abi3-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    -------------------------------- ------- 1.3/1.6 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 6.5 MB/s  0:00:00
# Building wheels for collected packages: multitasking, peewee
#   Building wheel for multitasking (pyproject.toml): started
#   Building wheel for multitasking (pyproject.toml): finished with status 'done'
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15703 sha256=9d5109ff1c91fc9895ecec3a247fb25806f6a8363331cc1627e4996060514471
#   Stored in directory: c:\users\gerha\appdata\local\pip\cache\wheels\1e\df\0f\e2bbb22d689b30c681feb5410ab64a2523437b34c8ecfc6476
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.18.3-py3-none-any.whl size=139181 sha256=eb713593404776d911005ef21113aeb507985b673978eaf87174b8208e1d5d8a
#   Stored in directory: c:\users\gerha\appdata\local\pip\cache\wheels\8c\a9\a4\df972cd49f865ffde174d9c5b26f14f08f8a363ed31e10ff91
# Successfully built multitasking peewee
# Installing collected packages: peewee, multitasking, curl_cffi, yfinance
#
#    ---------------------------------------- 0/4 [peewee]
#    -------------------- ------------------- 2/4 [curl_cffi]
#    ------------------------------ --------- 3/4 [yfinance]
#    ---------------------------------------- 4/4 [yfinance]
#
# Successfully installed curl_cffi-0.13.0 multitasking-0.0.12 peewee-3.18.3 yfinance-1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

# Define the ticker symbol
ticker_symbol = "AAPL"

# Download data from yfinance
aapl = yf.download(ticker_symbol, start="2024-10-24", end="2025-10-23")

# Display the first few rows
print(aapl.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2024-10-24  229.279648  229.528249  227.131732  228.692938  31109500
# 2024-10-25  230.114944  231.914813  228.285245  228.454292  38802300
# 2024-10-28  232.093765  233.416324  231.248531  232.014226  36087100
# 2024-10-29  232.362289  233.018599  231.019854  231.795487  35417200
# 2024-10-30  228.812271  232.163406  228.265346  231.308219  47070900

# %%
# %load_ext jupyter_ai
# %%ai openai-chat:gpt-4o
# Out:
# The jupyter_ai extension is already loaded. To reload it, use:
#   %reload_ext jupyter_ai
# UsageError: Line magic function `%%ai` not found.

# %%
# %ai hello
# Out:
# ---------------------------------------------------------------------------
# UsageError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_ipython().run_line_magic('ai', 'hello')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2504, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2502     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2503 with self.builtin_trap:
# -> 2504     result = fn(*args, **kwargs)
#    2506 # The code below prevents the output from being displayed
#    2507 # when using magics with decorator @output_can_be_silenced
#    2508 # when the last Python token in the expression is a ';'.
#    2509 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\anaconda3\Lib\site-packages\jupyter_ai_magics\magics.py:635, in AiMagics.ai(self, line, cell)
#     628     args = cell_magic_parser(
#     629         raw_args,
#     630         prog_name="%%ai",
#     631         standalone_mode=False,
#     632         default_map={"cell_magic_parser": default_map},
#     633     )
#     634 else:
# --> 635     args = line_magic_parser(
#     636         raw_args,
#     637         prog_name="%ai",
#     638         standalone_mode=False,
#     639         default_map={"error": default_map},
#     640     )
#     642 if args == 0 and self.default_language_model is None:
#     643     # this happens when `--help` is called on the root command, in which
#     644     # case we want to exit early.
#     645     return
#
# File ~\anaconda3\Lib\site-packages\click\core.py:1442, in Command.__call__(self, *args, **kwargs)
#    1440 def __call__(self, *args: t.Any, **kwargs: t.Any) -> t.Any:
#    1441     """Alias for :meth:`main`."""
# -> 1442     return self.main(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\click\core.py:1363, in Command.main(self, args, prog_name, complete_var, standalone_mode, windows_expand_args, **extra)
#    1361 try:
#    1362     with self.make_context(prog_name, args, **extra) as ctx:
# -> 1363         rv = self.invoke(ctx)
#    1364         if not standalone_mode:
#    1365             return rv
#
# File ~\anaconda3\Lib\site-packages\click\core.py:1824, in Group.invoke(self, ctx)
#    1820 if not self.chain:
#    1821     # Make sure the context is entered so we do not clean up
#    1822     # resources until the result processor has worked.
#    1823     with ctx:
# -> 1824         cmd_name, cmd, args = self.resolve_command(ctx, args)
#    1825         assert cmd is not None
#    1826         ctx.invoked_subcommand = cmd_name
#
# File ~\anaconda3\Lib\site-packages\click\core.py:1888, in Group.resolve_command(self, ctx, args)
#    1886     if _split_opt(cmd_name)[0]:
#    1887         self.parse_args(ctx, args)
# -> 1888     ctx.fail(_("No such command {name!r}.").format(name=original_cmd_name))
#    1889 return cmd_name if cmd else None, cmd, args[1:]
#
# File ~\anaconda3\Lib\site-packages\click\core.py:704, in Context.fail(self, message)
#     698 def fail(self, message: str) -> t.NoReturn:
#     699     """Aborts the execution of the program with a specific error
#     700     message.
#     701
#     702     :param message: the error message to fail with.
#     703     """
# --> 704     raise UsageError(message, self)
#
# UsageError: No such command 'hello'.
